# %%
# API 
# Application Programming Interface 

# Apis are interfaces that allow us to get data from an external typically on the internet

#When we attempt to get data from API we call this a request or a query 

# sometimes ApIS have security that limit access 
# some have reate limits, e.g., 100 requests per 24 hours

# Endpoint
# endpoints are URLS that we access to get some particular data --> where the data lives 
# Show endpoint
# for example tvmaze api  @ http://www.tvmaze.com/api
# http://api.tvmaze.com/shows/538
# 538 is unique identifier the tvmaze api uses for futurama
# each show has unique identifier 


# Data format:
#the data that comes back from API is usually in JSON or XML
#JSON = JavaScript Object Notation ; standard format 
# JSOn ends up looking a lot like nested dictionaries and lists (essentially doing key value pairs)

# %%
# to grab info from API, we need to make a request
#Making requests in python - using the request library
import requests

# the request library library allows us to make HTTP requests from python
# HTTP: HyperText Transfer Protocol  (basically webpages)
# https -> this just means http secure(the communication between you and the data source is encrypted)

#URL: Uniform Resource Locator 
#location on world wide web(www)
#a url is a human readable location - actual location of things on the internet (adresses)

# %%
#making requests: 
# request.get returns a response object
# then we call the .json method on the response object to get the json out.
# in python json will either give us a list or dictionary 
# response 200 means that teh request worked
futuramaDeets = requests.get("http://api.tvmaze.com/shows/538").json()
 
futuramaDeets
#futurama deets is a dictionary
type(futuramaDeets)
# Out:
# dict

# %%
#pretty print will print out data nicely
# careful because its not the actual order of the dictionary
import pprint
pprint.pprint(futuramaDeets)
# Out:
# {'_links': {'previousepisode': {'href': 'http://api.tvmaze.com/episodes/49411'},
#             'self': {'href': 'http://api.tvmaze.com/shows/538'}},
#  'externals': {'imdb': 'tt0149460', 'thetvdb': 73871, 'tvrage': 3628},
#  'genres': ['Comedy', 'Adventure', 'Science-Fiction'],
#  'id': 538,
#  'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/4/11403.jpg',
#            'original': 'http://static.tvmaze.com/uploads/images/original_untouched/4/11403.jpg'},
#  'language': 'English',
#  'name': 'Futurama',
#  'network': {'country': {'code': 'US',
#                          'name': 'United States',
#                          'timezone': 'America/New_York'},
#              'id': 23,
#              'name': 'Comedy Central'},
#  'officialSite': 'http://www.cc.com/shows/futurama',
#  'premiered': '1999-03-28',
#  'rating': {'average': 9},
#  'runtime': 30,
#  'schedule': {'days': ['Wednesday'], 'time': '22:00'},
#  'status': 'Ended',
#  'summary': '<p><b>Futurama</b> follows pizza guy Philip J. Fry, who reawakens '
#             'in 31st century New New York after a cryonics lab accident. Now '
#             'part of the Planet Express delivery crew, Fry travels to the '
#             'farthest reaches of the universe with his robot buddy Bender and '
#             'cyclopsian love interest Leela, discovering freaky mutants, '
#             'intergalactic conspiracies and other strange stuff.</p>',
#  'type': 'Animation',
#  'updated': 1593255316,
#  'url': 'http://www.tvmaze.com/shows/538/futurama',
#  'webChannel': None,
#  'weight': 89}

# %%
# working with APIS includes a lot of tinkering and working with the documentation


#using the search endpoint of tvmaze API
TrekQuery = requests.get("http://api.tvmaze.com/search/shows?q=Trek").json()
TrekQuery

# the shows endpoint returns a list of dictionaries, each dictionary is structured the same way, all have same keys, just differnt values
# Out:
# [{'score': 17.497307,
#   'show': {'id': 490,
#    'url': 'http://www.tvmaze.com/shows/490/star-trek',
#    'name': 'Star Trek',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Action', 'Adventure', 'Science-Fiction'],
#    'status': 'Ended',
#    'runtime': 60,
#    'premiered': '1966-09-08',
#    'officialSite': None,
#    'schedule': {'time': '20:30', 'days': ['Friday']},
#    'rating': {'average': 8.3},
#    'weight': 93,
#    'network': {'id': 1,
#     'name': 'NBC',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'webChannel': None,
#    'externals': {'tvrage': 5333, 'thetvdb': 77526, 'imdb': 'tt0060028'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/210/525135.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/210/525135.jpg'},
#    'summary': "<p>The original <b>Star Trek</b> series focuses on the 23rd century adventures of Captain James T. Kirk and the U.S.S. <i>Enterprise </i>(NCC-1701), a powerful interstellar spacecraft dispatched by Earth-based Starfleet Command to explore the galaxy. Kirk commands a crew of 430 men and women aboard his starship, which can travel at speeds surpassing the speed of light. Kirk's five-year mission—and his mandate from Starfleet—is to seek out new life and new civilizations, and to boldly go where no man has gone before.</p>",
#    'updated': 1573661322,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/490'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/44455'}}}},
#  {'score': 16.588379,
#   'show': {'id': 28343,
#    'url': 'http://www.tvmaze.com/shows/28343/after-trek',
#    'name': 'After Trek',
#    'type': 'Talk Show',
#    'language': 'English',
#    'genres': ['Science-Fiction'],
#    'status': 'Ended',
#    'runtime': 30,
#    'premiered': '2017-09-24',
#    'officialSite': 'http://www.cbs.com/shows/after-trek/',
#    'schedule': {'time': '21:30', 'days': ['Sunday']},
#    'rating': {'average': 2.5},
#    'weight': 0,
#    'network': None,
#    'webChannel': {'id': 107,
#     'name': 'CBS All Access',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'externals': {'tvrage': None, 'thetvdb': 335499, 'imdb': 'tt7423198'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/177/443886.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/177/443886.jpg'},
#    'summary': '<p><b>After Trek</b> will serve as the ultimate weekly forum for Star Trek fans with in-depth discussions and recaps of the latest <i>Star Trek: Discovery</i> episode. Each After Trek episode will feature host Matt Mira talking in-studio or via video feed with <i>Star Trek: Discovery</i> cast members and crew along with past Star Trek talent and celebrity fans. While watching, fans will be able to "engage" with the show via social and other interactive elements by using the hashtag #AfterTrek.</p>',
#    'updated': 1547862100,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/28343'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1409862'}}}},
#  {'score': 14.72428,
#   'show': {'id': 39323,
#    'url': 'http://www.tvmaze.com/shows/39323/star-trek-lower-decks',
#    'name': 'Star Trek: Lower Decks',
#    'type': 'Animation',
#    'language': 'English',
#    'genres': ['Comedy', 'Science-Fiction'],
#    'status': 'Running',
#    'runtime': 25,
#    'premiered': '2020-08-06',
#    'officialSite': 'https://www.cbs.com/shows/star-trek-lower-decks/',
#    'schedule': {'time': '', 'days': ['Thursday']},
#    'rating': {'average': 6.6},
#    'weight': 100,
#    'network': None,
#    'webChannel': {'id': 107,
#     'name': 'CBS All Access',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'externals': {'tvrage': None, 'thetvdb': 367138, 'imdb': 'tt9184820'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/266/666324.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/266/666324.jpg'},
#    'summary': "<p><b>Star Trek: Lower Decks</b> focuses on the support crew serving on one of Starfleet's least important ships, the U.S.S. Cerritos, in 2380. Ensigns Mariner, Boimler, Rutherford and Tendi have to keep up with their duties and their social lives, often while the ship is being rocked by a multitude of sci-fi anomalies.</p>",
#    'updated': 1599723000,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/39323'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1907771'},
#     'nextepisode': {'href': 'http://api.tvmaze.com/episodes/1907772'}}}},
#  {'score': 14.7206545,
#   'show': {'id': 7480,
#    'url': 'http://www.tvmaze.com/shows/7480/star-trek-discovery',
#    'name': 'Star Trek: Discovery',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Drama', 'Adventure', 'Science-Fiction'],
#    'status': 'Running',
#    'runtime': 60,
#    'premiered': '2017-09-24',
#    'officialSite': 'http://www.cbs.com/shows/star-trek-discovery/',
#    'schedule': {'time': '20:30', 'days': ['Thursday']},
#    'rating': {'average': 7.8},
#    'weight': 100,
#    'network': None,
#    'webChannel': {'id': 107,
#     'name': 'CBS All Access',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'externals': {'tvrage': None, 'thetvdb': 328711, 'imdb': 'tt5171438'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/272/680828.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/272/680828.jpg'},
#    'summary': '<p>Star Trek, one of the most iconic and influential global television franchises, returns 50 years after it first premiered, with <b>Star Trek: Discovery</b>. The series will feature a new ship, new characters and new missions, while embracing the same ideology and hope for the future that inspired a generation of dreamers and doers.</p>',
#    'updated': 1599600462,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/7480'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1613094'},
#     'nextepisode': {'href': 'http://api.tvmaze.com/episodes/1907769'}}}},
#  {'score': 14.678715,
#   'show': {'id': 42193,
#    'url': 'http://www.tvmaze.com/shows/42193/star-trek-picard',
#    'name': 'Star Trek: Picard',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Drama', 'Action', 'Science-Fiction'],
#    'status': 'Running',
#    'runtime': None,
#    'premiered': '2020-01-23',
#    'officialSite': 'https://www.cbs.com/shows/star-trek-picard/',
#    'schedule': {'time': '', 'days': ['Thursday']},
#    'rating': {'average': 8.2},
#    'weight': 99,
#    'network': None,
#    'webChannel': {'id': 107,
#     'name': 'CBS All Access',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'externals': {'tvrage': None, 'thetvdb': 364093, 'imdb': 'tt8806524'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/204/512066.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/204/512066.jpg'},
#    'summary': "<p>The series is set 20 years after Jean-Luc Picard's last appearance in <i>Star Trek: Nemesis</i> (2002), and follows him in the next chapter of his life.</p>",
#    'updated': 1585332027,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/42193'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1760966'}}}},
#  {'score': 14.559781,
#   'show': {'id': 39744,
#    'url': 'http://www.tvmaze.com/shows/39744/star-trek-short-treks',
#    'name': 'Star Trek: Short Treks',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Drama', 'Action', 'Science-Fiction'],
#    'status': 'To Be Determined',
#    'runtime': None,
#    'premiered': '2018-10-04',
#    'officialSite': 'https://www.cbs.com/shows/star-trek-short-treks/',
#    'schedule': {'time': '', 'days': []},
#    'rating': {'average': 8},
#    'weight': 98,
#    'network': None,
#    'webChannel': {'id': 107,
#     'name': 'CBS All Access',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'externals': {'tvrage': None, 'thetvdb': 376108, 'imdb': 'tt9059594'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/237/592645.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/237/592645.jpg'},
#    'summary': '<p><b>Star Trek: Short Treks</b> are short stories that allow fans to dive deeper into the key themes and characters that fit into <i>Star Trek: Discovery</i> and the expanding <i>Star Trek</i> universe.</p>',
#    'updated': 1588036195,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/39744'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1685792'}}}},
#  {'score': 14.555443,
#   'show': {'id': 49943,
#    'url': 'http://www.tvmaze.com/shows/49943/star-trek-odyssey',
#    'name': 'Star Trek: Odyssey',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Science-Fiction'],
#    'status': 'Ended',
#    'runtime': 30,
#    'premiered': '2007-09-01',
#    'officialSite': 'http://www.hiddenfrontier.net/productions/ody/',
#    'schedule': {'time': '', 'days': ['Saturday']},
#    'rating': {'average': None},
#    'weight': 0,
#    'network': None,
#    'webChannel': {'id': 21, 'name': 'YouTube', 'country': None},
#    'externals': {'tvrage': None, 'thetvdb': 126391, 'imdb': 'tt2074442'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/269/674747.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/269/674747.jpg'},
#    'summary': "<p>A Star Trek fan production based on the Homer's The Odyssey telling the story of a spaceship trying to go home after getting lost in the Andromeda Galaxy.</p>",
#    'updated': 1598503262,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/49943'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1920086'}}}},
#  {'score': 14.244775,
#   'show': {'id': 714,
#    'url': 'http://www.tvmaze.com/shows/714/star-trek-enterprise',
#    'name': 'Star Trek: Enterprise',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Action', 'Adventure', 'Science-Fiction'],
#    'status': 'Ended',
#    'runtime': 60,
#    'premiered': '2001-09-26',
#    'officialSite': None,
#    'schedule': {'time': '12:00', 'days': ['Friday']},
#    'rating': {'average': 8.2},
#    'weight': 94,
#    'network': {'id': 70,
#     'name': 'UPN',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'webChannel': None,
#    'externals': {'tvrage': 5335, 'thetvdb': 73893, 'imdb': 'tt0244365'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/6/15045.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/6/15045.jpg'},
#    'summary': "<p><b>Star Trek: Enterprise</b> (ENT) focuses on the 22nd century adventures of Captain Jonathan Archer aboard the Enterprise NX-01 during the early days of interstellar travel. The NX designation indicates that this Enterprise is an experimental prototype; AUnlike the starships of the four other <i>Star Trek </i>series, this Enterprise doesn't have deflector shields or phasers, but it does come equipped with a phase cannon and a rudimentary transporter that functions efficiently most of the time.</p>",
#    'updated': 1573608035,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/714'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/63356'}}}},
#  {'score': 14.235207,
#   'show': {'id': 492,
#    'url': 'http://www.tvmaze.com/shows/492/star-trek-voyager',
#    'name': 'Star Trek: Voyager',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Action', 'Adventure', 'Science-Fiction'],
#    'status': 'Ended',
#    'runtime': 60,
#    'premiered': '1995-01-16',
#    'officialSite': None,
#    'schedule': {'time': '21:00', 'days': ['Wednesday']},
#    'rating': {'average': 8.1},
#    'weight': 90,
#    'network': {'id': 70,
#     'name': 'UPN',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'webChannel': None,
#    'externals': {'tvrage': 5338, 'thetvdb': 74550, 'imdb': 'tt0112178'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/70/176260.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/70/176260.jpg'},
#    'summary': '<p><b>Star Trek: Voyager</b> (VOY) focuses on the 24th century adventures of Captain Kathryn Janeway aboard the U.S.S. Voyager. Smaller than either Kirk\'s or Picard\'s starships—its crew complement is only 150—Voyager is fast and powerful, and has the ability to land on a planet\'s surface. It is one of the most technologically advanced vessels in Starfleet, utilizing computer circuitry that incorporates synthetic neural tissue. Ironically, Janeway\'s inaugural mission aboard Voyager was to be her last in the Alpha quadrant. While attempting to capture the crew of a renegade Maquis vessel, both her ship and that of the Maquis were pulled into the distant Delta quadrant by powerful alien technology. Unfortunately, there would be no similar "express" route to take them home again. Stranded 70,000 light-years from Earth, Janeway convinced the Maquis to join her Starfleet crew and serve together during the long voyage back to Federation space.</p>',
#    'updated': 1585126273,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/492'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/44806'}}}},
#  {'score': 14.14155,
#   'show': {'id': 2173,
#    'url': 'http://www.tvmaze.com/shows/2173/star-trek-continues',
#    'name': 'Star Trek Continues',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Adventure', 'Science-Fiction'],
#    'status': 'Ended',
#    'runtime': 45,
#    'premiered': '2013-05-24',
#    'officialSite': 'http://www.startrekcontinues.com/',
#    'schedule': {'time': '21:00', 'days': ['Monday']},
#    'rating': {'average': 8.2},
#    'weight': 70,
#    'network': None,
#    'webChannel': {'id': 16,
#     'name': 'startrekcontinues.com',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'externals': {'tvrage': 46942, 'thetvdb': 264220, 'imdb': 'tt2732442'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/105/263130.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/105/263130.jpg'},
#    'summary': '<p><b>Star Trek Continues </b>is a fan-created science fiction series set in the <i>Star Trek </i>universe produced by Trek Continues Inc., Far From Home, and Dracogen. The series is an unofficial direct continuation of the third and last season of <i>Star Trek: The Original Series</i>, whose visual and storytelling features have been reproduced to recreate the same look-and-feel.</p><p>As with all such <i>Star Trek</i> fan productions, use of copyrighted and trademarked properties from the original series was allowed so long as the production is not-for-profit. Part of the funds necessary to produce the episodes were raised through a successful Kickstarter campaign, to which almost three thousand backers contributed.</p><p><i>Star Trek Continues</i> won a <i>Geekie Award</i> for "Best Web Series" in 2014 and has been very positively received by the critics, who praised the quality of the production, stating that the series has set a new standard for <i>Star Trek</i> fan productions.</p>',
#    'updated': 1594702808,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/2173'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1336446'}}}}]

# %%
for oneShow in TrekQuery:  # we are iterating through each show in this trek query - each consists of multiple dictionaries
    print(oneShow["show"]["name"])
    #prints value associated with with the show key in the oneshow
    print(oneShow["show"]["genres"])
    print()
# Out:
# Star Trek
# ['Action', 'Adventure', 'Science-Fiction']
#
# After Trek
# ['Science-Fiction']
#
# Star Trek: Lower Decks
# ['Comedy', 'Science-Fiction']
#
# Star Trek: Discovery
# ['Drama', 'Adventure', 'Science-Fiction']
#
# Star Trek: Picard
# ['Drama', 'Action', 'Science-Fiction']
#
# Star Trek: Short Treks
# ['Drama', 'Action', 'Science-Fiction']
#
# Star Trek: Odyssey
# ['Science-Fiction']
#
# Star Trek: Enterprise
# ['Action', 'Adventure', 'Science-Fiction']
#
# Star Trek: Voyager
# ['Action', 'Adventure', 'Science-Fiction']
#
# Star Trek Continues
# ['Adventure', 'Science-Fiction']

# %%
import requests 
import pprint 

# lets kook at eacg show returned from the query and look at information for each show using a different endpoint
# lets look at episodes (different entpoint)

#first we need an id
officeQuery = requests.get("http://api.tvmaze.com/search/shows?q=Office").json()

for oneShow in officeQuery:
    print(oneShow["show"]["name"])
    print("Summary: "+str(oneShow["show"]["summary"]))
    print("show ID:"+str(oneShow["show"]["id"]))
    print()
# Out:
# The Office
# Summary: <p>Steve Carell stars in <b>The Office</b>, a fresh and funny mockumentary-style glimpse into the daily interactions of the eccentric workers at the Dunder Mifflin paper supply company. Based on the smash-hit British series of the same name and adapted for American Television by Greg Daniels, this fast-paced comedy parodies contemporary American water-cooler culture. Earnest but clueless regional manager Michael Scott believes himself to be an exceptional boss and mentor, but actually receives more eye-rolls than respect from his oddball staff.</p>
# show ID:526
#
# The Office
# Summary: <p>A mockumentary about life in a mid-sized suboffice paper merchants in a bleak British industrial town, where manager David Brent thinks he's the coolest, funniest, and most popular boss ever. He isn't. That doesn't stop him from embarrassing himself in front of the cameras on a regular basis, whether from his political sermonizing, his stand-up 'comedy', or his incredibly unique dancing. Meanwhile, long-suffering Tim longs after Dawn the engaged receptionist and keeps himself sane by playing childish practical jokes on his insufferable, army-obsessed deskmate Gareth. Will the Slough office be closed? Will the BBC give David a game show? Will Tim and Dawn end up with each other? And more importantly, will Gareth realize what a hopeless prat he is?</p>
# show ID:1292
#
# Office Watch
# Summary: <p><b>Office Watch</b> is about what goes on in an office, showing the main characters struggling with a variety of very difficult coworkers but also captures blooming office romance.</p>
# show ID:44432
#
# Sweet and Salty Office
# Summary: <p>A single woman in her 30s talks about her work and love life over food.</p>
# show ID:38875
#
# The Naked Office
# Summary: <p><b>The Naked Office</b> attempts to help businesses get back on track by stripping away their problems using a revolutionary approach – going to work stark naked. With the recession still in full swing and companies fighting to stay afloat, the series investigates whether working naked will help employees to break down relationship boundaries by increasing positivity and productivity and explore whether flashing the flesh is the ultimate office equalizer.</p>
# show ID:36116
#
# The Office: Blackmail
# Summary: None
# show ID:49531
#
# Box Office
# Summary: <p>Hosted by cinema enthusiast Lisa Cannon, <b>Box Office</b> is a brand new movie show that will kick off on 3e on Wednesday 7th June at 8pm.</p><p>In collaboration with Virgin Media, <i>Box Office</i> will bring the wonderful world of new movies releases, the most talked about TV shows and the best box-sets you just have to binge watch, to a brand new weekly show on 3e.</p><p>With big name interviews, in depth reviews, behind-the-scenes footage and sneak-peaks of all the latest blockbuster films this is the not to be missed show for all fan-fanatics and TV addicts.</p>
# show ID:28775
#
# Electronic Office
# Summary: Ian McNaught Davis examines and explains the changing world of the office and shows how new technology is altering how people work.
# show ID:48226
#
# The Singing Office
# Summary: <p>Each week, hosts Joey Fatone and Mel B. surprise an office, hold an impromptu audition - in front of their co-workers - to create a team of the five best singers, and help them prepare for their time in the spotlight. Then, it's off to the stage for a choreographed sing-off to earn a spot in the finale and a chance to win $50,000. No office is safe this summer!</p>
# show ID:39299
#
# Office Uprising
# Summary: <p>An underachiever working at a major weapons manufacturer discovers his coworkers have been weaponized by an energy drink designed for the military.</p>
# show ID:34397

# %%
# office episode ID = 526
episodesQuery = requests.get("http://api.tvmaze.com/shows/526/episodes").json()
# Out:
# [{'id': 47640,
#   'url': 'http://www.tvmaze.com/episodes/47640/the-office-1x01-pilot',
#   'name': 'Pilot',
#   'season': 1,
#   'number': 1,
#   'airdate': '2005-03-24',
#   'airtime': '21:30',
#   'airstamp': '2005-03-25T02:30:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/49/124795.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/49/124795.jpg'},
#   'summary': '<p>A documentary crew arrives at Dundler Mifflin to observe the workplace. Michael Scott tries to paint a happy picture while facing potential downsizing.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47640'}}},
#  {'id': 47641,
#   'url': 'http://www.tvmaze.com/episodes/47641/the-office-1x02-diversity-day',
#   'name': 'Diversity Day',
#   'season': 1,
#   'number': 2,
#   'airdate': '2005-03-29',
#   'airtime': '21:30',
#   'airstamp': '2005-03-30T02:30:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/49/124859.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/49/124859.jpg'},
#   'summary': '<p>Corporate sends in a consultant after Michael attempts to imitate a Chris Rock routine. Michael ends up staging his own Diversity Day event.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47641'}}},
#  {'id': 47642,
#   'url': 'http://www.tvmaze.com/episodes/47642/the-office-1x03-health-care',
#   'name': 'Health Care',
#   'season': 1,
#   'number': 3,
#   'airdate': '2005-04-05',
#   'airtime': '21:30',
#   'airstamp': '2005-04-06T01:30:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/50/125614.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/50/125614.jpg'},
#   'summary': '<p>Dwight ends up in charge of picking a new health care plan.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47642'}}},
#  {'id': 47643,
#   'url': 'http://www.tvmaze.com/episodes/47643/the-office-1x04-the-alliance',
#   'name': 'The Alliance',
#   'season': 1,
#   'number': 4,
#   'airdate': '2005-04-12',
#   'airtime': '21:00',
#   'airstamp': '2005-04-13T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/50/125615.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/50/125615.jpg'},
#   'summary': '<p>With Dwight worried about downsizing, Jim agrees to an alliance; Michael tries to increase moral be throwing a birthday party for Meredith.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47643'}}},
#  {'id': 47644,
#   'url': 'http://www.tvmaze.com/episodes/47644/the-office-1x05-basketball',
#   'name': 'Basketball',
#   'season': 1,
#   'number': 5,
#   'airdate': '2005-04-19',
#   'airtime': '21:00',
#   'airstamp': '2005-04-20T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/50/126301.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/50/126301.jpg'},
#   'summary': '<p>Michael challenges the warehouse staff to a basketball game versus the office staff.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47644'}}},
#  {'id': 47645,
#   'url': 'http://www.tvmaze.com/episodes/47645/the-office-1x06-hot-girl',
#   'name': 'Hot Girl',
#   'season': 1,
#   'number': 6,
#   'airdate': '2005-04-26',
#   'airtime': '21:00',
#   'airstamp': '2005-04-27T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/50/126302.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/50/126302.jpg'},
#   'summary': '<p>Several male staff members vie for the attention of an attractive purse sales woman.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47645'}}},
#  {'id': 47646,
#   'url': 'http://www.tvmaze.com/episodes/47646/the-office-2x01-the-dundies',
#   'name': 'The Dundies',
#   'season': 2,
#   'number': 1,
#   'airdate': '2005-09-20',
#   'airtime': '21:00',
#   'airstamp': '2005-09-21T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/50/127495.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/50/127495.jpg'},
#   'summary': '<p>Michael hosts the annual Dundies awards.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47646'}}},
#  {'id': 47647,
#   'url': 'http://www.tvmaze.com/episodes/47647/the-office-2x02-sexual-harassment',
#   'name': 'Sexual Harassment',
#   'season': 2,
#   'number': 2,
#   'airdate': '2005-09-27',
#   'airtime': '21:00',
#   'airstamp': '2005-09-28T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/51/127560.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/51/127560.jpg'},
#   'summary': "<p>Michael's continual sending of explicit e-mail forwards forces Dunder Mifflin to review it's sexual harassment policy; Pam's mom makes a visit to the office.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47647'}}},
#  {'id': 47648,
#   'url': 'http://www.tvmaze.com/episodes/47648/the-office-2x03-office-olympics',
#   'name': 'Office Olympics',
#   'season': 2,
#   'number': 3,
#   'airdate': '2005-10-04',
#   'airtime': '21:00',
#   'airstamp': '2005-10-05T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/51/127912.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/51/127912.jpg'},
#   'summary': '<p>With Michael and Dwight out of the house, Jim organizes an office Olympics.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47648'}}},
#  {'id': 47649,
#   'url': 'http://www.tvmaze.com/episodes/47649/the-office-2x04-the-fire',
#   'name': 'The Fire',
#   'season': 2,
#   'number': 4,
#   'airdate': '2005-10-11',
#   'airtime': '21:00',
#   'airstamp': '2005-10-12T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/244/612242.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/244/612242.jpg'},
#   'summary': '<p>A fire starts in the office kitchen.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47649'}}},
#  {'id': 47650,
#   'url': 'http://www.tvmaze.com/episodes/47650/the-office-2x05-halloween',
#   'name': 'Halloween',
#   'season': 2,
#   'number': 5,
#   'airdate': '2005-10-18',
#   'airtime': '21:00',
#   'airstamp': '2005-10-19T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486287.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486287.jpg'},
#   'summary': '<p>Michael has to fire someone on Halloween.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47650'}}},
#  {'id': 47651,
#   'url': 'http://www.tvmaze.com/episodes/47651/the-office-2x06-the-fight',
#   'name': 'The Fight',
#   'season': 2,
#   'number': 6,
#   'airdate': '2005-11-01',
#   'airtime': '21:00',
#   'airstamp': '2005-11-02T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486288.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486288.jpg'},
#   'summary': '<p>Michael challenges Dwight to a fight at his martial arts studio.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47651'}}},
#  {'id': 47652,
#   'url': 'http://www.tvmaze.com/episodes/47652/the-office-2x07-the-client',
#   'name': 'The Client',
#   'season': 2,
#   'number': 7,
#   'airdate': '2005-11-08',
#   'airtime': '21:00',
#   'airstamp': '2005-11-09T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486289.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486289.jpg'},
#   'summary': "<p>Jan helps Michael with an important pitch for a client; The staff discovers a screenplay in Michael's office.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47652'}}},
#  {'id': 47653,
#   'url': 'http://www.tvmaze.com/episodes/47653/the-office-2x08-performance-review',
#   'name': 'Performance Review',
#   'season': 2,
#   'number': 8,
#   'airdate': '2005-11-15',
#   'airtime': '21:00',
#   'airstamp': '2005-11-16T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486290.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486290.jpg'},
#   'summary': "<p>Michael uses each employee's performance review to discuss his relationship with Jan.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47653'}}},
#  {'id': 47654,
#   'url': 'http://www.tvmaze.com/episodes/47654/the-office-2x09-e-mail-surveillance',
#   'name': 'E-Mail Surveillance',
#   'season': 2,
#   'number': 9,
#   'airdate': '2005-11-22',
#   'airtime': '21:00',
#   'airstamp': '2005-11-23T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486291.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486291.jpg'},
#   'summary': '<p>The office staff finds out that Michael has set up e-mail surveillance.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47654'}}},
#  {'id': 47655,
#   'url': 'http://www.tvmaze.com/episodes/47655/the-office-2x10-christmas-party',
#   'name': 'Christmas Party',
#   'season': 2,
#   'number': 10,
#   'airdate': '2005-12-06',
#   'airtime': '21:00',
#   'airstamp': '2005-12-07T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/244/612243.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/244/612243.jpg'},
#   'summary': '<p>At the office Christmas party, Michael changes secret santa into a gift exchange.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47655'}}},
#  {'id': 47656,
#   'url': 'http://www.tvmaze.com/episodes/47656/the-office-2x11-booze-cruise',
#   'name': 'Booze Cruise',
#   'season': 2,
#   'number': 11,
#   'airdate': '2006-01-05',
#   'airtime': '21:00',
#   'airstamp': '2006-01-06T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/245/612694.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/245/612694.jpg'},
#   'summary': '<p>Michael takes the staff on a booze cruise.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47656'}}},
#  {'id': 47657,
#   'url': 'http://www.tvmaze.com/episodes/47657/the-office-2x12-the-injury',
#   'name': 'The Injury',
#   'season': 2,
#   'number': 12,
#   'airdate': '2006-01-12',
#   'airtime': '21:00',
#   'airstamp': '2006-01-13T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486294.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486294.jpg'},
#   'summary': '<p>Michael accidentally burns his foot on his George Foreman Grill, but insists on coming to work anyway. When none of his employees, except for Dwight , help him, Michael feels under-appreciated. Meanwhile, Dwight starts acting strangely nice to everyone, especially Pam.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47657'}}},
#  {'id': 47658,
#   'url': 'http://www.tvmaze.com/episodes/47658/the-office-2x13-the-secret',
#   'name': 'The Secret',
#   'season': 2,
#   'number': 13,
#   'airdate': '2006-01-19',
#   'airtime': '21:00',
#   'airstamp': '2006-01-20T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486295.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486295.jpg'},
#   'summary': '<p>Jim is forced into spending time with Michael so that he will not reveal Jim\'s feelings for Pam. Meanwhile, Oscar takes a "sick day" and Dwight investigates whether he is actually sick.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47658'}}},
#  {'id': 47659,
#   'url': 'http://www.tvmaze.com/episodes/47659/the-office-2x14-the-carpet',
#   'name': 'The Carpet',
#   'season': 2,
#   'number': 14,
#   'airdate': '2006-01-26',
#   'airtime': '21:00',
#   'airstamp': '2006-01-27T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486296.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486296.jpg'},
#   'summary': '<p>A disgusting "thing" – implied to be human feces – is left in Michael\'s office, and he tries to discover who did it. While his carpet is being replaced, he uses Jim\'s desk, forcing him to move away from Pam into the annex.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47659'}}},
#  {'id': 47660,
#   'url': 'http://www.tvmaze.com/episodes/47660/the-office-2x15-boys-and-girls',
#   'name': 'Boys and Girls',
#   'season': 2,
#   'number': 15,
#   'airdate': '2006-02-02',
#   'airtime': '21:00',
#   'airstamp': '2006-02-03T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486297.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486297.jpg'},
#   'summary': "<p>When Jan comes to the office for a women in the office session, Michael stages a men's only session.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47660'}}},
#  {'id': 47661,
#   'url': 'http://www.tvmaze.com/episodes/47661/the-office-2x16-valentines-day',
#   'name': "Valentine's Day",
#   'season': 2,
#   'number': 16,
#   'airdate': '2006-02-09',
#   'airtime': '21:00',
#   'airstamp': '2006-02-10T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486298.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486298.jpg'},
#   'summary': "<p>Michael has a big meeting in New York with Jan and the companies new CEO; Pam deals with all the Valentine's Day deliveries hoping Roy will remember to send her something.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47661'}}},
#  {'id': 47662,
#   'url': 'http://www.tvmaze.com/episodes/47662/the-office-2x17-dwights-speech',
#   'name': "Dwight's Speech",
#   'season': 2,
#   'number': 17,
#   'airdate': '2006-03-02',
#   'airtime': '21:00',
#   'airstamp': '2006-03-03T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/245/612700.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/245/612700.jpg'},
#   'summary': '<p>Dwight has to make a big speech when he is named Salesmen of the Year.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47662'}}},
#  {'id': 47663,
#   'url': 'http://www.tvmaze.com/episodes/47663/the-office-2x18-take-your-daughter-to-work-day',
#   'name': 'Take Your Daughter to Work Day',
#   'season': 2,
#   'number': 18,
#   'airdate': '2006-03-16',
#   'airtime': '21:00',
#   'airstamp': '2006-03-17T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486431.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486431.jpg'},
#   'summary': '<p>Staff members bring their children to work.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47663'}}},
#  {'id': 47664,
#   'url': 'http://www.tvmaze.com/episodes/47664/the-office-2x19-michaels-birthday',
#   'name': "Michael's Birthday",
#   'season': 2,
#   'number': 19,
#   'airdate': '2006-03-30',
#   'airtime': '21:00',
#   'airstamp': '2006-03-31T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486432.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486432.jpg'},
#   'summary': "<p>Michael's birthday coincides with Kevin awaiting the news to see if he has skin cancer.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47664'}}},
#  {'id': 47665,
#   'url': 'http://www.tvmaze.com/episodes/47665/the-office-2x20-drug-testing',
#   'name': 'Drug Testing',
#   'season': 2,
#   'number': 20,
#   'airdate': '2006-04-27',
#   'airtime': '21:00',
#   'airstamp': '2006-04-28T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486433.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486433.jpg'},
#   'summary': '<p>After Dwight finds a joint in the office park, he goes overboard with an investigation.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47665'}}},
#  {'id': 47666,
#   'url': 'http://www.tvmaze.com/episodes/47666/the-office-2x21-conflict-resolution',
#   'name': 'Conflict Resolution',
#   'season': 2,
#   'number': 21,
#   'airdate': '2006-05-04',
#   'airtime': '21:00',
#   'airstamp': '2006-05-05T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/245/612703.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/245/612703.jpg'},
#   'summary': "<p>Michael's attempt to resolve conflict resolution in the office just leads to more conflict.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47666'}}},
#  {'id': 47667,
#   'url': 'http://www.tvmaze.com/episodes/47667/the-office-2x22-casino-night',
#   'name': 'Casino Night',
#   'season': 2,
#   'number': 22,
#   'airdate': '2006-05-11',
#   'airtime': '21:00',
#   'airstamp': '2006-05-12T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486435.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486435.jpg'},
#   'summary': '<p>The office holds a casino night for charity in the warehouse.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47667'}}},
#  {'id': 47668,
#   'url': 'http://www.tvmaze.com/episodes/47668/the-office-3x01-gay-witch-hunt',
#   'name': 'Gay Witch Hunt',
#   'season': 3,
#   'number': 1,
#   'airdate': '2006-09-21',
#   'airtime': '21:00',
#   'airstamp': '2006-09-22T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486855.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486855.jpg'},
#   'summary': '<p>Michael finds out that Oscar is gay after Oscar files a complaint when Michael uses a homosexual slur.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47668'}}},
#  {'id': 47669,
#   'url': 'http://www.tvmaze.com/episodes/47669/the-office-3x02-the-convention',
#   'name': 'The Convention',
#   'season': 3,
#   'number': 2,
#   'airdate': '2006-09-28',
#   'airtime': '21:00',
#   'airstamp': '2006-09-29T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486856.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486856.jpg'},
#   'summary': '<p>Michael and Dwight go to a convention that Jim is also attending; Pam goes on her first date after her engagement.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47669'}}},
#  {'id': 47670,
#   'url': 'http://www.tvmaze.com/episodes/47670/the-office-3x03-the-coup',
#   'name': 'The Coup',
#   'season': 3,
#   'number': 3,
#   'airdate': '2006-10-05',
#   'airtime': '21:00',
#   'airstamp': '2006-10-06T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486857.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486857.jpg'},
#   'summary': '<p>After Jan discovers Michael has been having "movie Monday\'s", Angela encourages Dwight to make a move for Michael\'s job.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47670'}}},
#  {'id': 47671,
#   'url': 'http://www.tvmaze.com/episodes/47671/the-office-3x04-grief-counseling',
#   'name': 'Grief Counseling',
#   'season': 3,
#   'number': 4,
#   'airdate': '2006-10-12',
#   'airtime': '21:00',
#   'airstamp': '2006-10-13T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486858.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486858.jpg'},
#   'summary': '<p>Michael organizes grief counseling sessions following the death of his old boss, Ed Truck.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47671'}}},
#  {'id': 47672,
#   'url': 'http://www.tvmaze.com/episodes/47672/the-office-3x05-initiation',
#   'name': 'Initiation',
#   'season': 3,
#   'number': 5,
#   'airdate': '2006-10-19',
#   'airtime': '21:00',
#   'airstamp': '2006-10-20T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486859.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486859.jpg'},
#   'summary': '<p>Dwight initiates Ryan into his new job as a salesmen at Dunder Mifflin; Pam is tasked with keeping track of everything Michael does during the day by Jan.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47672'}}},
#  {'id': 47673,
#   'url': 'http://www.tvmaze.com/episodes/47673/the-office-3x06-diwali',
#   'name': 'Diwali',
#   'season': 3,
#   'number': 6,
#   'airdate': '2006-11-02',
#   'airtime': '21:00',
#   'airstamp': '2006-11-03T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486860.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486860.jpg'},
#   'summary': '<p>Kelly invites the office staff to a Diwali celebration.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47673'}}},
#  {'id': 47674,
#   'url': 'http://www.tvmaze.com/episodes/47674/the-office-3x07-branch-closing',
#   'name': 'Branch Closing',
#   'season': 3,
#   'number': 7,
#   'airdate': '2006-11-09',
#   'airtime': '21:00',
#   'airstamp': '2006-11-10T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486861.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486861.jpg'},
#   'summary': '<p>Jan gives Michael the news that the Scranton branch is closing.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47674'}}},
#  {'id': 47675,
#   'url': 'http://www.tvmaze.com/episodes/47675/the-office-3x08-the-merger',
#   'name': 'The Merger',
#   'season': 3,
#   'number': 8,
#   'airdate': '2006-11-16',
#   'airtime': '21:00',
#   'airstamp': '2006-11-17T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486862.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486862.jpg'},
#   'summary': '<p>Jim and other members of the Stamford branch have their first day at Scranton.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47675'}}},
#  {'id': 47676,
#   'url': 'http://www.tvmaze.com/episodes/47676/the-office-3x09-the-convict',
#   'name': 'The Convict',
#   'season': 3,
#   'number': 9,
#   'airdate': '2006-11-30',
#   'airtime': '21:00',
#   'airstamp': '2006-12-01T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486863.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486863.jpg'},
#   'summary': '<p>The office discovers than one of the new Stamford people is a former convict.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47676'}}},
#  {'id': 47677,
#   'url': 'http://www.tvmaze.com/episodes/47677/the-office-3x10-a-benihana-christmas-1',
#   'name': 'A Benihana Christmas (1)',
#   'season': 3,
#   'number': 10,
#   'airdate': '2006-12-14',
#   'airtime': '21:00',
#   'airstamp': '2006-12-15T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486864.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486864.jpg'},
#   'summary': '<p>Michael gets dumped by Carol; Pam and Karen start a rival party planning committee.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47677'}}},
#  {'id': 47678,
#   'url': 'http://www.tvmaze.com/episodes/47678/the-office-3x11-a-benihana-christmas-2',
#   'name': 'A Benihana Christmas (2)',
#   'season': 3,
#   'number': 11,
#   'airdate': '2006-12-14',
#   'airtime': '21:00',
#   'airstamp': '2006-12-15T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486867.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486867.jpg'},
#   'summary': '<p>Michael gets dumped by Carol; Karen and Pam start a rival party planning committee.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47678'}}},
#  {'id': 47679,
#   'url': 'http://www.tvmaze.com/episodes/47679/the-office-3x12-back-from-vacation',
#   'name': 'Back from Vacation',
#   'season': 3,
#   'number': 12,
#   'airdate': '2007-01-04',
#   'airtime': '21:00',
#   'airstamp': '2007-01-05T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486869.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486869.jpg'},
#   'summary': '<p>Michael returns from his vacation and accidentally sends a picture of Jan sunbathing to everyone in the office.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47679'}}},
#  {'id': 47680,
#   'url': 'http://www.tvmaze.com/episodes/47680/the-office-3x13-traveling-salesmen',
#   'name': 'Traveling Salesmen',
#   'season': 3,
#   'number': 13,
#   'airdate': '2007-01-11',
#   'airtime': '21:00',
#   'airstamp': '2007-01-12T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486871.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486871.jpg'},
#   'summary': '<p>Dwight does a favor for Angela that puts him in hot water with Michael; The sales team heads out on partner sales calls.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47680'}}},
#  {'id': 47681,
#   'url': 'http://www.tvmaze.com/episodes/47681/the-office-3x14-the-return',
#   'name': 'The Return',
#   'season': 3,
#   'number': 14,
#   'airdate': '2007-01-18',
#   'airtime': '21:00',
#   'airstamp': '2007-01-19T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486873.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486873.jpg'},
#   'summary': '<p>Oscar returns to work; Dwight gets a job at Staples.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47681'}}},
#  {'id': 47682,
#   'url': 'http://www.tvmaze.com/episodes/47682/the-office-3x15-ben-franklin',
#   'name': 'Ben Franklin',
#   'season': 3,
#   'number': 15,
#   'airdate': '2007-02-01',
#   'airtime': '21:00',
#   'airstamp': '2007-02-02T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/245/612715.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/245/612715.jpg'},
#   'summary': '<p>The ladies of the office throw a bridal shower for Phyllis; Michael tries to throw a rival bachelor party for Bob.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47682'}}},
#  {'id': 47683,
#   'url': 'http://www.tvmaze.com/episodes/47683/the-office-3x16-phyllis-wedding',
#   'name': "Phyllis' Wedding",
#   'season': 3,
#   'number': 16,
#   'airdate': '2007-02-08',
#   'airtime': '21:00',
#   'airstamp': '2007-02-09T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486876.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486876.jpg'},
#   'summary': "<p>Michael tries to expand his role at Phyllis' wedding; Pam realizes that Phyllis stole all of her ideas from her canceled wedding to Roy.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47683'}}},
#  {'id': 47684,
#   'url': 'http://www.tvmaze.com/episodes/47684/the-office-3x17-business-school',
#   'name': 'Business School',
#   'season': 3,
#   'number': 17,
#   'airdate': '2007-02-15',
#   'airtime': '21:00',
#   'airstamp': '2007-02-16T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486877.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486877.jpg'},
#   'summary': "<p>Michael is a guest speaker at Ryan's business school class; A bat gets lose in the office; Pam has an art show that she invites the entire office too.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47684'}}},
#  {'id': 47685,
#   'url': 'http://www.tvmaze.com/episodes/47685/the-office-3x18-cocktails',
#   'name': 'Cocktails',
#   'season': 3,
#   'number': 18,
#   'airdate': '2007-02-22',
#   'airtime': '21:00',
#   'airstamp': '2007-02-23T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/245/612717.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/245/612717.jpg'},
#   'summary': '<p>David Wallace hosts a party at his host which Michael, Jan, Dwight, Jim and Karen attend; The rest of the office staff go out for Happy Hour.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47685'}}},
#  {'id': 47686,
#   'url': 'http://www.tvmaze.com/episodes/47686/the-office-3x19-the-negotiation',
#   'name': 'The Negotiation',
#   'season': 3,
#   'number': 19,
#   'airdate': '2007-04-05',
#   'airtime': '21:00',
#   'airstamp': '2007-04-06T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486879.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486879.jpg'},
#   'summary': '<p>Dwight saves Jim when Roy shows up at the office planning to hit him for kissing Pam; Darryl asks Michael for a raise which leads to Michael asking for a raise from Jan.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47686'}}},
#  {'id': 47687,
#   'url': 'http://www.tvmaze.com/episodes/47687/the-office-3x20-safety-training',
#   'name': 'Safety Training',
#   'season': 3,
#   'number': 20,
#   'airdate': '2007-04-12',
#   'airtime': '21:00',
#   'airstamp': '2007-04-13T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/245/612721.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/245/612721.jpg'},
#   'summary': '<p>The office staff undergoes safety training; Andy returns from anger management training.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47687'}}},
#  {'id': 47688,
#   'url': 'http://www.tvmaze.com/episodes/47688/the-office-3x21-product-recall',
#   'name': 'Product Recall',
#   'season': 3,
#   'number': 21,
#   'airdate': '2007-04-26',
#   'airtime': '21:00',
#   'airstamp': '2007-04-27T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486881.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486881.jpg'},
#   'summary': '<p>The office staff deal with a breach in quality control when an obscene water mark ends up their paper. </p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47688'}}},
#  {'id': 47689,
#   'url': 'http://www.tvmaze.com/episodes/47689/the-office-3x22-womens-appreciation',
#   'name': "Women's Appreciation",
#   'season': 3,
#   'number': 22,
#   'airdate': '2007-05-03',
#   'airtime': '21:00',
#   'airstamp': '2007-05-04T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/245/612723.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/245/612723.jpg'},
#   'summary': "<p>After Phyllis is flashed in the parking lot, Michael arranges a women's appreciation day.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47689'}}},
#  {'id': 47690,
#   'url': 'http://www.tvmaze.com/episodes/47690/the-office-3x23-beach-games',
#   'name': 'Beach Games',
#   'season': 3,
#   'number': 23,
#   'airdate': '2007-05-10',
#   'airtime': '21:00',
#   'airstamp': '2007-05-11T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486883.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486883.jpg'},
#   'summary': '<p>The office attends beach day which Michael uses to try and determine who would replace him if he gets a job at corporate. </p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47690'}}},
#  {'id': 47691,
#   'url': 'http://www.tvmaze.com/episodes/47691/the-office-3x24-the-job-1',
#   'name': 'The Job (1)',
#   'season': 3,
#   'number': 24,
#   'airdate': '2007-05-17',
#   'airtime': '21:00',
#   'airstamp': '2007-05-18T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486884.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486884.jpg'},
#   'summary': '<p>Michael, Jim and Karen interview for a job at corporate; Michael appoints Dwight as regional manager.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47691'}}},
#  {'id': 47692,
#   'url': 'http://www.tvmaze.com/episodes/47692/the-office-3x25-the-job-2',
#   'name': 'The Job (2)',
#   'season': 3,
#   'number': 25,
#   'airdate': '2007-05-17',
#   'airtime': '21:00',
#   'airstamp': '2007-05-18T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486885.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486885.jpg'},
#   'summary': '<p>Michael, Jim and Karen interview for a job at corporate; Michael appoints Dwight as regional manager.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47692'}}},
#  {'id': 47693,
#   'url': 'http://www.tvmaze.com/episodes/47693/the-office-4x01-fun-run-1',
#   'name': 'Fun Run (1)',
#   'season': 4,
#   'number': 1,
#   'airdate': '2007-09-27',
#   'airtime': '21:00',
#   'airstamp': '2007-09-28T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486886.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486886.jpg'},
#   'summary': '<p>Michael accidentally runs over Meredith in the parking lot which results in Michael arranging a 5K fun run for her.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47693'}}},
#  {'id': 47694,
#   'url': 'http://www.tvmaze.com/episodes/47694/the-office-4x02-fun-run-2',
#   'name': 'Fun Run (2)',
#   'season': 4,
#   'number': 2,
#   'airdate': '2007-09-27',
#   'airtime': '21:00',
#   'airstamp': '2007-09-28T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486887.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486887.jpg'},
#   'summary': '<p>Michael accidentally runs over Meredith in the parking lot which results in Michael arranging a 5K fun run for her</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47694'}}},
#  {'id': 47695,
#   'url': 'http://www.tvmaze.com/episodes/47695/the-office-4x03-dunder-mifflin-infinity-1',
#   'name': 'Dunder Mifflin Infinity (1)',
#   'season': 4,
#   'number': 3,
#   'airdate': '2007-10-04',
#   'airtime': '21:00',
#   'airstamp': '2007-10-05T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486888.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486888.jpg'},
#   'summary': "<p>Michael is resistant to the new ideas the Ryan brings to the company; Jim and Pam's relationship is exposed to the entire office.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47695'}}},
#  {'id': 47696,
#   'url': 'http://www.tvmaze.com/episodes/47696/the-office-4x04-dunder-mifflin-infinity-2',
#   'name': 'Dunder Mifflin Infinity (2)',
#   'season': 4,
#   'number': 4,
#   'airdate': '2007-10-04',
#   'airtime': '21:00',
#   'airstamp': '2007-10-05T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486889.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486889.jpg'},
#   'summary': '<p>Michael sets out to win clients back the old fashion way.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47696'}}},
#  {'id': 47697,
#   'url': 'http://www.tvmaze.com/episodes/47697/the-office-4x05-launch-party-1',
#   'name': 'Launch Party (1)',
#   'season': 4,
#   'number': 5,
#   'airdate': '2007-10-11',
#   'airtime': '21:00',
#   'airstamp': '2007-10-12T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486890.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486890.jpg'},
#   'summary': '<p>The Dunder Mifflin website launches; Dwight gets into a paper selling war with the new website.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47697'}}},
#  {'id': 47698,
#   'url': 'http://www.tvmaze.com/episodes/47698/the-office-4x06-launch-party-2',
#   'name': 'Launch Party (2)',
#   'season': 4,
#   'number': 6,
#   'airdate': '2007-10-11',
#   'airtime': '21:00',
#   'airstamp': '2007-10-12T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486891.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486891.jpg'},
#   'summary': "<p>Michael is upset when he realizes he wasn't invited to attend the actual launch party in New York; Andy pursues Angela.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47698'}}},
#  {'id': 47699,
#   'url': 'http://www.tvmaze.com/episodes/47699/the-office-4x07-money-1',
#   'name': 'Money (1)',
#   'season': 4,
#   'number': 7,
#   'airdate': '2007-10-18',
#   'airtime': '21:00',
#   'airstamp': '2007-10-19T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486892.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486892.jpg'},
#   'summary': "<p>Michael takes a second job as supporting Jan is draining his finances; Jim and Pam stay at Dwight's farm.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47699'}}},
#  {'id': 47700,
#   'url': 'http://www.tvmaze.com/episodes/47700/the-office-4x08-money-2',
#   'name': 'Money (2)',
#   'season': 4,
#   'number': 8,
#   'airdate': '2007-10-18',
#   'airtime': '21:00',
#   'airstamp': '2007-10-19T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486893.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486893.jpg'},
#   'summary': '<p>Oscar helps Michael with his finances; Andy continues to pursue Angela.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47700'}}},
#  {'id': 47701,
#   'url': 'http://www.tvmaze.com/episodes/47701/the-office-4x09-local-ad',
#   'name': 'Local Ad',
#   'season': 4,
#   'number': 9,
#   'airdate': '2007-10-25',
#   'airtime': '21:00',
#   'airstamp': '2007-10-26T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486894.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486894.jpg'},
#   'summary': '<p>Michael believes he can make a better TV ad than the professionals Dunder Mifflin sent.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47701'}}},
#  {'id': 47702,
#   'url': 'http://www.tvmaze.com/episodes/47702/the-office-4x10-branch-wars',
#   'name': 'Branch Wars',
#   'season': 4,
#   'number': 10,
#   'airdate': '2007-11-01',
#   'airtime': '21:00',
#   'airstamp': '2007-11-02T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486895.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486895.jpg'},
#   'summary': '<p>Michael and Dwight set out to pull a prank on Utica when they find out that Karen is trying to steal Stanley.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47702'}}},
#  {'id': 47703,
#   'url': 'http://www.tvmaze.com/episodes/47703/the-office-4x11-survivor-man',
#   'name': 'Survivor Man',
#   'season': 4,
#   'number': 11,
#   'airdate': '2007-11-08',
#   'airtime': '21:00',
#   'airstamp': '2007-11-09T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486896.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486896.jpg'},
#   'summary': "<p>Michael sets out to survivor in the wilderness after Ryan doesn't invite him on a retreat; Jim is put in charge of the office while Michael is going and he attempts to change the birthday party policy. </p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47703'}}},
#  {'id': 47704,
#   'url': 'http://www.tvmaze.com/episodes/47704/the-office-4x12-the-deposition',
#   'name': 'The Deposition',
#   'season': 4,
#   'number': 12,
#   'airdate': '2007-11-15',
#   'airtime': '21:00',
#   'airstamp': '2007-11-16T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486897.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486897.jpg'},
#   'summary': "<p>Michael tries to play both sides when he has to give a deposition for Jan's lawsuit against Dunder Mifflin.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47704'}}},
#  {'id': 47705,
#   'url': 'http://www.tvmaze.com/episodes/47705/the-office-4x13-dinner-party',
#   'name': 'Dinner Party',
#   'season': 4,
#   'number': 13,
#   'airdate': '2008-04-10',
#   'airtime': '21:00',
#   'airstamp': '2008-04-11T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486898.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486898.jpg'},
#   'summary': '<p>Michael traps Pam and Jim, Angela and Andy into a dinner party with him and Jan.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47705'}}},
#  {'id': 47706,
#   'url': 'http://www.tvmaze.com/episodes/47706/the-office-4x14-chair-model',
#   'name': 'Chair Model',
#   'season': 4,
#   'number': 14,
#   'airdate': '2008-04-17',
#   'airtime': '21:00',
#   'airstamp': '2008-04-18T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486899.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486899.jpg'},
#   'summary': "<p>Michael becomes obsessed with a model in a chair catalog; Kevin and Andy set out to reclaim the office's parking spaces.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47706'}}},
#  {'id': 47707,
#   'url': 'http://www.tvmaze.com/episodes/47707/the-office-4x15-night-out',
#   'name': 'Night Out',
#   'season': 4,
#   'number': 15,
#   'airdate': '2008-04-24',
#   'airtime': '21:00',
#   'airstamp': '2008-04-25T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486900.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486900.jpg'},
#   'summary': '<p>Michael and Dwight head to New York to party with Ryan; Jim gets the office to work late to avoid coming in on Saturday and they get locked in the parking lot.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47707'}}},
#  {'id': 47708,
#   'url': 'http://www.tvmaze.com/episodes/47708/the-office-4x16-did-i-stutter',
#   'name': 'Did I Stutter?',
#   'season': 4,
#   'number': 16,
#   'airdate': '2008-05-01',
#   'airtime': '21:00',
#   'airstamp': '2008-05-02T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486901.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486901.jpg'},
#   'summary': "<p>Michael has to deal with Stanley's open insubordination at a meeting.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47708'}}},
#  {'id': 47709,
#   'url': 'http://www.tvmaze.com/episodes/47709/the-office-4x17-job-fair',
#   'name': 'Job Fair',
#   'season': 4,
#   'number': 17,
#   'airdate': '2008-05-08',
#   'airtime': '21:00',
#   'airstamp': '2008-05-09T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486902.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486902.jpg'},
#   'summary': '<p>Michael, Pam, Darryl and Oscar attend a job fair; Jim, Kevin and Andy play a round of golf with a perspective client.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47709'}}},
#  {'id': 47710,
#   'url': 'http://www.tvmaze.com/episodes/47710/the-office-4x18-goodbye-toby-1',
#   'name': 'Goodbye, Toby (1)',
#   'season': 4,
#   'number': 18,
#   'airdate': '2008-05-15',
#   'airtime': '21:00',
#   'airstamp': '2008-05-16T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486903.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486903.jpg'},
#   'summary': '<p>Michael becomes infatuated with the woman replacing Toby; Jim plan to propose to Pam is upstaged by Andy; Michael gets a surprise from Jan.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47710'}}},
#  {'id': 47711,
#   'url': 'http://www.tvmaze.com/episodes/47711/the-office-4x19-goodbye-toby-2',
#   'name': 'Goodbye, Toby (2)',
#   'season': 4,
#   'number': 19,
#   'airdate': '2008-05-15',
#   'airtime': '21:00',
#   'airstamp': '2008-05-16T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486904.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486904.jpg'},
#   'summary': '<p>Michael becomes infatuated with the woman replacing Toby; Jim plan to propose to Pam is upstaged by Andy; Michael gets a surprise from Jan.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47711'}}},
#  {'id': 47712,
#   'url': 'http://www.tvmaze.com/episodes/47712/the-office-5x01-weight-loss-1',
#   'name': 'Weight Loss (1)',
#   'season': 5,
#   'number': 1,
#   'airdate': '2008-09-25',
#   'airtime': '21:00',
#   'airstamp': '2008-09-26T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/194/486905.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/194/486905.jpg'},
#   'summary': '<p>The office staff goes to extremes when they participate in a weight loss contest run by corporate.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47712'}}},
#  {'id': 47713,
#   'url': 'http://www.tvmaze.com/episodes/47713/the-office-5x02-weight-loss-2',
#   'name': 'Weight Loss (2)',
#   'season': 5,
#   'number': 2,
#   'airdate': '2008-09-25',
#   'airtime': '21:00',
#   'airstamp': '2008-09-26T01:00:00+00:00',
#   'runtime': 30,
# ...
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488767.jpg'},
#   'summary': '<p>The office is joined by two new guys who the office dubs new Dwight and new Jim. Andy tries to force Nellie out.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47816'}}},
#  {'id': 47817,
#   'url': 'http://www.tvmaze.com/episodes/47817/the-office-9x02-roys-wedding',
#   'name': "Roy's Wedding",
#   'season': 9,
#   'number': 2,
#   'airdate': '2012-09-27',
#   'airtime': '21:00',
#   'airstamp': '2012-09-28T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488768.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488768.jpg'},
#   'summary': "<p>Jim and Pam attend Roy's wedding. Nellie tries to initiate a special project involving charity. </p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47817'}}},
#  {'id': 47818,
#   'url': 'http://www.tvmaze.com/episodes/47818/the-office-9x03-andys-ancestry',
#   'name': "Andy's Ancestry",
#   'season': 9,
#   'number': 3,
#   'airdate': '2012-10-04',
#   'airtime': '21:00',
#   'airstamp': '2012-10-05T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488769.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488769.jpg'},
#   'summary': '<p>Nellie convinces Andy that he is distantly related to Michelle Obama; Pam tries to teach Nellie how to drive.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47818'}}},
#  {'id': 47819,
#   'url': 'http://www.tvmaze.com/episodes/47819/the-office-9x04-work-bus',
#   'name': 'Work Bus',
#   'season': 9,
#   'number': 4,
#   'airdate': '2012-10-18',
#   'airtime': '21:00',
#   'airstamp': '2012-10-19T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488770.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488770.jpg'},
#   'summary': '<p>Jim convinces Dwight that the office has safety issues so Jim sets up a temporary office in the parking lot.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47819'}}},
#  {'id': 47820,
#   'url': 'http://www.tvmaze.com/episodes/47820/the-office-9x05-here-comes-treble',
#   'name': 'Here Comes Treble',
#   'season': 9,
#   'number': 5,
#   'airdate': '2012-10-25',
#   'airtime': '21:00',
#   'airstamp': '2012-10-26T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488771.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488771.jpg'},
#   'summary': "<p>It's Halloween at the office and Andy invites his college's capella group to perform at the party; Jim and Pam disagree over how much to invest in the new sports business.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47820'}}},
#  {'id': 47821,
#   'url': 'http://www.tvmaze.com/episodes/47821/the-office-9x06-the-boat',
#   'name': 'The Boat',
#   'season': 9,
#   'number': 6,
#   'airdate': '2012-11-08',
#   'airtime': '21:00',
#   'airstamp': '2012-11-09T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488772.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488772.jpg'},
#   'summary': "<p>Andy deals with the aftermath of his family losing all their money; Jim, Pam and Nellie pulls a radio interview prank on Dwight; Kevin finds out about Oscar and Angela's husband.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47821'}}},
#  {'id': 47822,
#   'url': 'http://www.tvmaze.com/episodes/47822/the-office-9x07-the-whale',
#   'name': 'The Whale',
#   'season': 9,
#   'number': 7,
#   'airdate': '2012-11-15',
#   'airtime': '21:00',
#   'airstamp': '2012-11-16T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488774.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488774.jpg'},
#   'summary': '<p>The ladies of the office try and help Dwight pitch to a female client; Angela and Oscar think the Senator is cheating on them.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47822'}}},
#  {'id': 47823,
#   'url': 'http://www.tvmaze.com/episodes/47823/the-office-9x08-the-target',
#   'name': 'The Target',
#   'season': 9,
#   'number': 8,
#   'airdate': '2012-11-29',
#   'airtime': '21:00',
#   'airstamp': '2012-11-30T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488775.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488775.jpg'},
#   'summary': '<p>Angela wants to put a hit out on Oscar; Jim has to wine and dine Phyllis and Stanley for a favor.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47823'}}},
#  {'id': 47824,
#   'url': 'http://www.tvmaze.com/episodes/47824/the-office-9x09-dwight-christmas',
#   'name': 'Dwight Christmas',
#   'season': 9,
#   'number': 9,
#   'airdate': '2012-12-06',
#   'airtime': '21:00',
#   'airstamp': '2012-12-07T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488776.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488776.jpg'},
#   'summary': '<p>When the staff forgets about Christmas, Dwight is able to throw his version of Christmas.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47824'}}},
#  {'id': 47825,
#   'url': 'http://www.tvmaze.com/episodes/47825/the-office-9x10-lice',
#   'name': 'Lice',
#   'season': 9,
#   'number': 10,
#   'airdate': '2013-01-10',
#   'airtime': '21:00',
#   'airstamp': '2013-01-11T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488777.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488777.jpg'},
#   'summary': '<p>Pam brings lice into the office and lets Meredith take the fall.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47825'}}},
#  {'id': 47826,
#   'url': 'http://www.tvmaze.com/episodes/47826/the-office-9x11-suit-warehouse',
#   'name': 'Suit Warehouse',
#   'season': 9,
#   'number': 11,
#   'airdate': '2013-01-17',
#   'airtime': '21:00',
#   'airstamp': '2013-01-18T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488778.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488778.jpg'},
#   'summary': "<p>Dwight gets Clark to help him with a sale; Darryl has an interview at Jim's company.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47826'}}},
#  {'id': 47827,
#   'url': 'http://www.tvmaze.com/episodes/47827/the-office-9x12-customer-loyalty',
#   'name': 'Customer Loyalty',
#   'season': 9,
#   'number': 12,
#   'airdate': '2013-01-24',
#   'airtime': '21:00',
#   'airstamp': '2013-01-25T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488779.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488779.jpg'},
#   'summary': "<p>The office believes that Erin and Pete have feelings for each other; Jim misses his daughter's recital because of a business meeting.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47827'}}},
#  {'id': 47828,
#   'url': 'http://www.tvmaze.com/episodes/47828/the-office-9x13-junior-salesman',
#   'name': 'Junior Salesman',
#   'season': 9,
#   'number': 13,
#   'airdate': '2013-01-31',
#   'airtime': '21:00',
#   'airstamp': '2013-02-01T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488780.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488780.jpg'},
#   'summary': "<p>Clark has to compete against a bunch of Dwight's friends and family for the job of junior salesman.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47828'}}},
#  {'id': 47829,
#   'url': 'http://www.tvmaze.com/episodes/47829/the-office-9x14-vandalism',
#   'name': 'Vandalism',
#   'season': 9,
#   'number': 14,
#   'airdate': '2013-01-31',
#   'airtime': '21:00',
#   'airstamp': '2013-02-01T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488781.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488781.jpg'},
#   'summary': '<p>Pam is upset when she finds her mural has been defaced; Darryl finds out Jim is a slob when they sublet an apartment together in Philly.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47829'}}},
#  {'id': 47830,
#   'url': 'http://www.tvmaze.com/episodes/47830/the-office-9x15-couples-discount',
#   'name': 'Couples Discount',
#   'season': 9,
#   'number': 15,
#   'airdate': '2013-02-07',
#   'airtime': '21:00',
#   'airstamp': '2013-02-08T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488782.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488782.jpg'},
#   'summary': "<p>The staff celebrates Valentine's Day by going out to a local nail salon for couple's discounts; Jim and Pam have lunch with Brian.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47830'}}},
#  {'id': 47831,
#   'url': 'http://www.tvmaze.com/episodes/47831/the-office-9x16-moving-on',
#   'name': 'Moving On',
#   'season': 9,
#   'number': 16,
#   'airdate': '2013-02-14',
#   'airtime': '21:00',
#   'airstamp': '2013-02-15T02:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488783.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488783.jpg'},
#   'summary': '<p>Andy learns that Erin is now seeing Pete; Pam interviews for a job in Philadelphia.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47831'}}},
#  {'id': 47832,
#   'url': 'http://www.tvmaze.com/episodes/47832/the-office-9x17-the-farm',
#   'name': 'The Farm',
#   'season': 9,
#   'number': 17,
#   'airdate': '2013-03-14',
#   'airtime': '21:00',
#   'airstamp': '2013-03-15T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488784.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488784.jpg'},
#   'summary': "<p>After Dwight's aunt dies, his sister and brother return for her funeral; Todd Packer returns to the office.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47832'}}},
#  {'id': 47833,
#   'url': 'http://www.tvmaze.com/episodes/47833/the-office-9x18-promos',
#   'name': 'Promos',
#   'season': 9,
#   'number': 18,
#   'airdate': '2013-04-04',
#   'airtime': '21:00',
#   'airstamp': '2013-04-05T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488785.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488785.jpg'},
#   'summary': '<p>The promo for the documentary is finally released.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47833'}}},
#  {'id': 47834,
#   'url': 'http://www.tvmaze.com/episodes/47834/the-office-9x19-stairmageddon',
#   'name': 'Stairmageddon',
#   'season': 9,
#   'number': 19,
#   'airdate': '2013-04-11',
#   'airtime': '21:00',
#   'airstamp': '2013-04-12T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488786.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488786.jpg'},
#   'summary': '<p>Stanley refuses to go on a sales call with Dwight because the elevator is broke; Jim and Pam begin marriage counseling. </p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47834'}}},
#  {'id': 47835,
#   'url': 'http://www.tvmaze.com/episodes/47835/the-office-9x20-paper-airplane',
#   'name': 'Paper Airplane',
#   'season': 9,
#   'number': 20,
#   'airdate': '2013-04-25',
#   'airtime': '21:00',
#   'airstamp': '2013-04-26T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488787.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488787.jpg'},
#   'summary': '<p>The staff competes in a paper airplane contest.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47835'}}},
#  {'id': 47836,
#   'url': 'http://www.tvmaze.com/episodes/47836/the-office-9x21-livin-the-dream',
#   'name': "Livin' the Dream",
#   'season': 9,
#   'number': 21,
#   'airdate': '2013-05-02',
#   'airtime': '21:00',
#   'airstamp': '2013-05-03T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488788.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488788.jpg'},
#   'summary': '<p>Andy quits as regional manager to focus on his acting career; Jim dedicates more time at Dunder Mifflin to save his marriage.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47836'}}},
#  {'id': 47837,
#   'url': 'http://www.tvmaze.com/episodes/47837/the-office-9x22-aarm-1',
#   'name': 'A.A.R.M. (1)',
#   'season': 9,
#   'number': 22,
#   'airdate': '2013-05-09',
#   'airtime': '21:00',
#   'airstamp': '2013-05-10T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488789.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488789.jpg'},
#   'summary': '<p>Andy auditions for a singing competition; Dwight hires an assistant to his assistant to the regional manager...himself; Kevin is jealous of Phillip.</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47837'}}},
#  {'id': 47838,
#   'url': 'http://www.tvmaze.com/episodes/47838/the-office-9x23-aarm-2',
#   'name': 'A.A.R.M. (2)',
#   'season': 9,
#   'number': 23,
#   'airdate': '2013-05-09',
#   'airtime': '21:00',
#   'airstamp': '2013-05-10T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488794.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488794.jpg'},
#   'summary': '<p>Andy auditions for a singing competition; Dwight hires an assistant to his assistant to the regional manager...himself; Kevin is jealous of Phillip</p>',
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/47838'}}},
#  {'id': 711197,
#   'url': 'http://www.tvmaze.com/episodes/711197/the-office-9x24-finale-1',
#   'name': 'Finale (1)',
#   'season': 9,
#   'number': 24,
#   'airdate': '2013-05-16',
#   'airtime': '21:00',
#   'airstamp': '2013-05-17T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488813.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488813.jpg'},
#   'summary': "<p>The office staff reunites for a panel discussion and Dwight and Angela's wedding.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/711197'}}},
#  {'id': 711203,
#   'url': 'http://www.tvmaze.com/episodes/711203/the-office-9x25-finale-2',
#   'name': 'Finale (2)',
#   'season': 9,
#   'number': 25,
#   'airdate': '2013-05-16',
#   'airtime': '21:00',
#   'airstamp': '2013-05-17T01:00:00+00:00',
#   'runtime': 30,
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/195/488816.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/195/488816.jpg'},
#   'summary': "<p>The office staff reunites for a panel discussion and Dwight and Angela's wedding.</p>",
#   '_links': {'self': {'href': 'http://api.tvmaze.com/episodes/711203'}}}]

# %%
trekQuery = requests.get("http://api.tvmaze.com/search/shows?q=Trek").json()
trekQuery
# Out:
# [{'score': 17.497307,
#   'show': {'id': 490,
#    'url': 'http://www.tvmaze.com/shows/490/star-trek',
#    'name': 'Star Trek',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Action', 'Adventure', 'Science-Fiction'],
#    'status': 'Ended',
#    'runtime': 60,
#    'premiered': '1966-09-08',
#    'officialSite': None,
#    'schedule': {'time': '20:30', 'days': ['Friday']},
#    'rating': {'average': 8.3},
#    'weight': 93,
#    'network': {'id': 1,
#     'name': 'NBC',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'webChannel': None,
#    'externals': {'tvrage': 5333, 'thetvdb': 77526, 'imdb': 'tt0060028'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/210/525135.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/210/525135.jpg'},
#    'summary': "<p>The original <b>Star Trek</b> series focuses on the 23rd century adventures of Captain James T. Kirk and the U.S.S. <i>Enterprise </i>(NCC-1701), a powerful interstellar spacecraft dispatched by Earth-based Starfleet Command to explore the galaxy. Kirk commands a crew of 430 men and women aboard his starship, which can travel at speeds surpassing the speed of light. Kirk's five-year mission—and his mandate from Starfleet—is to seek out new life and new civilizations, and to boldly go where no man has gone before.</p>",
#    'updated': 1573661322,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/490'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/44455'}}}},
#  {'score': 16.588379,
#   'show': {'id': 28343,
#    'url': 'http://www.tvmaze.com/shows/28343/after-trek',
#    'name': 'After Trek',
#    'type': 'Talk Show',
#    'language': 'English',
#    'genres': ['Science-Fiction'],
#    'status': 'Ended',
#    'runtime': 30,
#    'premiered': '2017-09-24',
#    'officialSite': 'http://www.cbs.com/shows/after-trek/',
#    'schedule': {'time': '21:30', 'days': ['Sunday']},
#    'rating': {'average': 2.5},
#    'weight': 0,
#    'network': None,
#    'webChannel': {'id': 107,
#     'name': 'CBS All Access',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'externals': {'tvrage': None, 'thetvdb': 335499, 'imdb': 'tt7423198'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/177/443886.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/177/443886.jpg'},
#    'summary': '<p><b>After Trek</b> will serve as the ultimate weekly forum for Star Trek fans with in-depth discussions and recaps of the latest <i>Star Trek: Discovery</i> episode. Each After Trek episode will feature host Matt Mira talking in-studio or via video feed with <i>Star Trek: Discovery</i> cast members and crew along with past Star Trek talent and celebrity fans. While watching, fans will be able to "engage" with the show via social and other interactive elements by using the hashtag #AfterTrek.</p>',
#    'updated': 1547862100,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/28343'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1409862'}}}},
#  {'score': 14.72428,
#   'show': {'id': 39323,
#    'url': 'http://www.tvmaze.com/shows/39323/star-trek-lower-decks',
#    'name': 'Star Trek: Lower Decks',
#    'type': 'Animation',
#    'language': 'English',
#    'genres': ['Comedy', 'Science-Fiction'],
#    'status': 'Running',
#    'runtime': 25,
#    'premiered': '2020-08-06',
#    'officialSite': 'https://www.cbs.com/shows/star-trek-lower-decks/',
#    'schedule': {'time': '', 'days': ['Thursday']},
#    'rating': {'average': 6.6},
#    'weight': 100,
#    'network': None,
#    'webChannel': {'id': 107,
#     'name': 'CBS All Access',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'externals': {'tvrage': None, 'thetvdb': 367138, 'imdb': 'tt9184820'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/266/666324.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/266/666324.jpg'},
#    'summary': "<p><b>Star Trek: Lower Decks</b> focuses on the support crew serving on one of Starfleet's least important ships, the U.S.S. Cerritos, in 2380. Ensigns Mariner, Boimler, Rutherford and Tendi have to keep up with their duties and their social lives, often while the ship is being rocked by a multitude of sci-fi anomalies.</p>",
#    'updated': 1599723000,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/39323'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1907771'},
#     'nextepisode': {'href': 'http://api.tvmaze.com/episodes/1907772'}}}},
#  {'score': 14.7206545,
#   'show': {'id': 7480,
#    'url': 'http://www.tvmaze.com/shows/7480/star-trek-discovery',
#    'name': 'Star Trek: Discovery',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Drama', 'Adventure', 'Science-Fiction'],
#    'status': 'Running',
#    'runtime': 60,
#    'premiered': '2017-09-24',
#    'officialSite': 'http://www.cbs.com/shows/star-trek-discovery/',
#    'schedule': {'time': '20:30', 'days': ['Thursday']},
#    'rating': {'average': 7.8},
#    'weight': 100,
#    'network': None,
#    'webChannel': {'id': 107,
#     'name': 'CBS All Access',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'externals': {'tvrage': None, 'thetvdb': 328711, 'imdb': 'tt5171438'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/272/680828.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/272/680828.jpg'},
#    'summary': '<p>Star Trek, one of the most iconic and influential global television franchises, returns 50 years after it first premiered, with <b>Star Trek: Discovery</b>. The series will feature a new ship, new characters and new missions, while embracing the same ideology and hope for the future that inspired a generation of dreamers and doers.</p>',
#    'updated': 1599600462,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/7480'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1613094'},
#     'nextepisode': {'href': 'http://api.tvmaze.com/episodes/1907769'}}}},
#  {'score': 14.678715,
#   'show': {'id': 42193,
#    'url': 'http://www.tvmaze.com/shows/42193/star-trek-picard',
#    'name': 'Star Trek: Picard',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Drama', 'Action', 'Science-Fiction'],
#    'status': 'Running',
#    'runtime': None,
#    'premiered': '2020-01-23',
#    'officialSite': 'https://www.cbs.com/shows/star-trek-picard/',
#    'schedule': {'time': '', 'days': ['Thursday']},
#    'rating': {'average': 8.2},
#    'weight': 99,
#    'network': None,
#    'webChannel': {'id': 107,
#     'name': 'CBS All Access',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'externals': {'tvrage': None, 'thetvdb': 364093, 'imdb': 'tt8806524'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/204/512066.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/204/512066.jpg'},
#    'summary': "<p>The series is set 20 years after Jean-Luc Picard's last appearance in <i>Star Trek: Nemesis</i> (2002), and follows him in the next chapter of his life.</p>",
#    'updated': 1585332027,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/42193'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1760966'}}}},
#  {'score': 14.559781,
#   'show': {'id': 39744,
#    'url': 'http://www.tvmaze.com/shows/39744/star-trek-short-treks',
#    'name': 'Star Trek: Short Treks',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Drama', 'Action', 'Science-Fiction'],
#    'status': 'To Be Determined',
#    'runtime': None,
#    'premiered': '2018-10-04',
#    'officialSite': 'https://www.cbs.com/shows/star-trek-short-treks/',
#    'schedule': {'time': '', 'days': []},
#    'rating': {'average': 8},
#    'weight': 98,
#    'network': None,
#    'webChannel': {'id': 107,
#     'name': 'CBS All Access',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'externals': {'tvrage': None, 'thetvdb': 376108, 'imdb': 'tt9059594'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/237/592645.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/237/592645.jpg'},
#    'summary': '<p><b>Star Trek: Short Treks</b> are short stories that allow fans to dive deeper into the key themes and characters that fit into <i>Star Trek: Discovery</i> and the expanding <i>Star Trek</i> universe.</p>',
#    'updated': 1588036195,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/39744'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1685792'}}}},
#  {'score': 14.555443,
#   'show': {'id': 49943,
#    'url': 'http://www.tvmaze.com/shows/49943/star-trek-odyssey',
#    'name': 'Star Trek: Odyssey',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Science-Fiction'],
#    'status': 'Ended',
#    'runtime': 30,
#    'premiered': '2007-09-01',
#    'officialSite': 'http://www.hiddenfrontier.net/productions/ody/',
#    'schedule': {'time': '', 'days': ['Saturday']},
#    'rating': {'average': None},
#    'weight': 0,
#    'network': None,
#    'webChannel': {'id': 21, 'name': 'YouTube', 'country': None},
#    'externals': {'tvrage': None, 'thetvdb': 126391, 'imdb': 'tt2074442'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/269/674747.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/269/674747.jpg'},
#    'summary': "<p>A Star Trek fan production based on the Homer's The Odyssey telling the story of a spaceship trying to go home after getting lost in the Andromeda Galaxy.</p>",
#    'updated': 1598503262,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/49943'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1920086'}}}},
#  {'score': 14.244775,
#   'show': {'id': 714,
#    'url': 'http://www.tvmaze.com/shows/714/star-trek-enterprise',
#    'name': 'Star Trek: Enterprise',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Action', 'Adventure', 'Science-Fiction'],
#    'status': 'Ended',
#    'runtime': 60,
#    'premiered': '2001-09-26',
#    'officialSite': None,
#    'schedule': {'time': '12:00', 'days': ['Friday']},
#    'rating': {'average': 8.2},
#    'weight': 94,
#    'network': {'id': 70,
#     'name': 'UPN',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'webChannel': None,
#    'externals': {'tvrage': 5335, 'thetvdb': 73893, 'imdb': 'tt0244365'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/6/15045.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/6/15045.jpg'},
#    'summary': "<p><b>Star Trek: Enterprise</b> (ENT) focuses on the 22nd century adventures of Captain Jonathan Archer aboard the Enterprise NX-01 during the early days of interstellar travel. The NX designation indicates that this Enterprise is an experimental prototype; AUnlike the starships of the four other <i>Star Trek </i>series, this Enterprise doesn't have deflector shields or phasers, but it does come equipped with a phase cannon and a rudimentary transporter that functions efficiently most of the time.</p>",
#    'updated': 1573608035,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/714'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/63356'}}}},
#  {'score': 14.235207,
#   'show': {'id': 492,
#    'url': 'http://www.tvmaze.com/shows/492/star-trek-voyager',
#    'name': 'Star Trek: Voyager',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Action', 'Adventure', 'Science-Fiction'],
#    'status': 'Ended',
#    'runtime': 60,
#    'premiered': '1995-01-16',
#    'officialSite': None,
#    'schedule': {'time': '21:00', 'days': ['Wednesday']},
#    'rating': {'average': 8.1},
#    'weight': 90,
#    'network': {'id': 70,
#     'name': 'UPN',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'webChannel': None,
#    'externals': {'tvrage': 5338, 'thetvdb': 74550, 'imdb': 'tt0112178'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/70/176260.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/70/176260.jpg'},
#    'summary': '<p><b>Star Trek: Voyager</b> (VOY) focuses on the 24th century adventures of Captain Kathryn Janeway aboard the U.S.S. Voyager. Smaller than either Kirk\'s or Picard\'s starships—its crew complement is only 150—Voyager is fast and powerful, and has the ability to land on a planet\'s surface. It is one of the most technologically advanced vessels in Starfleet, utilizing computer circuitry that incorporates synthetic neural tissue. Ironically, Janeway\'s inaugural mission aboard Voyager was to be her last in the Alpha quadrant. While attempting to capture the crew of a renegade Maquis vessel, both her ship and that of the Maquis were pulled into the distant Delta quadrant by powerful alien technology. Unfortunately, there would be no similar "express" route to take them home again. Stranded 70,000 light-years from Earth, Janeway convinced the Maquis to join her Starfleet crew and serve together during the long voyage back to Federation space.</p>',
#    'updated': 1585126273,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/492'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/44806'}}}},
#  {'score': 14.14155,
#   'show': {'id': 2173,
#    'url': 'http://www.tvmaze.com/shows/2173/star-trek-continues',
#    'name': 'Star Trek Continues',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Adventure', 'Science-Fiction'],
#    'status': 'Ended',
#    'runtime': 45,
#    'premiered': '2013-05-24',
#    'officialSite': 'http://www.startrekcontinues.com/',
#    'schedule': {'time': '21:00', 'days': ['Monday']},
#    'rating': {'average': 8.2},
#    'weight': 70,
#    'network': None,
#    'webChannel': {'id': 16,
#     'name': 'startrekcontinues.com',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'}},
#    'externals': {'tvrage': 46942, 'thetvdb': 264220, 'imdb': 'tt2732442'},
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/105/263130.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/105/263130.jpg'},
#    'summary': '<p><b>Star Trek Continues </b>is a fan-created science fiction series set in the <i>Star Trek </i>universe produced by Trek Continues Inc., Far From Home, and Dracogen. The series is an unofficial direct continuation of the third and last season of <i>Star Trek: The Original Series</i>, whose visual and storytelling features have been reproduced to recreate the same look-and-feel.</p><p>As with all such <i>Star Trek</i> fan productions, use of copyrighted and trademarked properties from the original series was allowed so long as the production is not-for-profit. Part of the funds necessary to produce the episodes were raised through a successful Kickstarter campaign, to which almost three thousand backers contributed.</p><p><i>Star Trek Continues</i> won a <i>Geekie Award</i> for "Best Web Series" in 2014 and has been very positively received by the critics, who praised the quality of the production, stating that the series has set a new standard for <i>Star Trek</i> fan productions.</p>',
#    'updated': 1594702808,
#    '_links': {'self': {'href': 'http://api.tvmaze.com/shows/2173'},
#     'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1336446'}}}}]

# %%
# nested requests
# each request is based on the request that comes before

for trekShow in trekQuery:
    print("SHOW NAME: "+trekShow["show"]["name"])
    showID = trekShow["show"]["id"]
    trekEpRequest = requests.get("http://api.tvmaze.com/shows/"+str(showID)+"/episodes").json()
    episodeCounter = 0
    for episode in trekEpRequest:
        episodeCounter+=1
        print(episode["name"])
    print("Total episodes:"+str(episodeCounter))
    print()
    print()
# Out:
# SHOW NAME: Star Trek
# The Man Trap
# Charlie X
# Where No Man Has Gone Before
# The Naked Time
# The Enemy Within
# Mudd's Women
# What Are Little Girls Made Of?
# Miri
# Dagger of the Mind
# The Corbomite Maneuver
# The Menagerie (1)
# The Menagerie (2)
# The Conscience of the King
# Balance of Terror
# Shore Leave
# The Galileo Seven
# The Squire of Gothos
# Arena
# Tomorrow is Yesterday
# Court Martial
# The Return of the Archons
# Space Seed
# A Taste of Armageddon
# This Side of Paradise
# The Devil in the Dark
# Errand of Mercy
# The Alternative Factor
# The City on the Edge of Forever
# Operation: Annihilate!
# Amok Time
# Who Mourns for Adonais?
# The Changeling
# Mirror, Mirror
# The Apple
# The Doomsday Machine
# Catspaw
# I, Mudd
# Metamorphosis
# Journey to Babel
# Friday's Child
# The Deadly Years
# Obsession
# Wolf in the Fold
# The Trouble with Tribbles
# The Gamesters of Triskelion
# A Piece of the Action
# The Immunity Syndrome
# A Private Little War
# Return to Tomorrow
# Patterns of Force
# By Any Other Name
# The Omega Glory
# The Ultimate Computer
# Bread and Circuses
# Assignment: Earth
# Spock's Brain
# The Enterprise Incident
# The Paradise Syndrome
# And the Children Shall Lead
# Is There in Truth No Beauty?
# Spectre of the Gun
# Day of the Dove
# For the World is Hollow and I Have Touched the Sky
# The Tholian Web
# Plato's Stepchildren
# Wink of an Eye
# The Empath
# Elaan of Troyius
# Whom Gods Destroy
# Let That Be Your Last Battlefield
# The Mark of Gideon
# That Which Survives
# The Lights of Zetar
# Requiem for Methuselah
# The Way to Eden
# The Cloud Minders
# The Savage Curtain
# All Our Yesterdays
# Turnabout Intruder
# Total episodes:79
#
#
# SHOW NAME: After Trek
# Episode 1
# Episode 2
# Episode 3
# Episode 4
# Episode 5
# Episode 6
# Episode 7
# Episode 8
# Episode 9
# Episode 10
# Episode 11
# Episode 12
# Episode 13
# Episode 14
# Total episodes:14
#
#
# SHOW NAME: Star Trek: Lower Decks
# Second Contact
# Envoys
# Temporal Edict
# Moist Vessel
# Cupid's Errant Arrow
# Terminal Provocations
# TBA
# TBA
# TBA
# TBA
# Total episodes:10
#
#
# SHOW NAME: Star Trek: Discovery
# The Vulcan Hello
# Battle at the Binary Stars
# Context Is for Kings
# The Butcher's Knife Cares Not for the Lamb's Cry
# Choose Your Pain
# Lethe
# Magic to Make the Sanest Man Go Mad
# Si Vis Pacem, Para Bellum
# Into the Forest I Go
# Despite Yourself
# The Wolf Inside
# Vaulting Ambition
# What's Past Is Prologue
# The War Without, the War Within
# Will You Take My Hand?
# Brother
# New Eden
# Point of Light
# An Obol for Charon
# Saints of Imperfection
# The Sounds of Thunder
# Light and Shadows
# If Memory Serves
# Project Daedalus
# The Red Angel
# Perpetual Infinity
# Through the Valley of Shadows
# Such Sweet Sorrow
# Such Sweet Sorrow, Part 2
# TBA
# Total episodes:30
#
#
# SHOW NAME: Star Trek: Picard
# Remembrance
# Maps and Legends
# The End is the Beginning
# Absolute Candor
# Stardust City Rag
# The Impossible Box
# Nepenthe
# Broken Pieces
# Et in Arcadia Ego, Part 1
# Et in Arcadia Ego, Part 2
# Total episodes:10
#
#
# SHOW NAME: Star Trek: Short Treks
# Runaway
# Calypso
# The Brightest Star
# The Escape Artist
# Q&A
# The Trouble with Edward
# Ask Not
# Ephraim & Dot
# The Girl Who Made the Stars
# Children of Mars
# Total episodes:10
#
#
# SHOW NAME: Star Trek: Odyssey
# Iliad
# The Wine Dark Sea
# The Lotus Eaters
# Vile Gods
# Keepers of the Wind
# On the Knees of the Gods
# The Immortal Loom
# For All Time
# Tossed Upon the Shore
# Total episodes:9
#
#
# SHOW NAME: Star Trek: Enterprise
# Broken Bow (1)
# Broken Bow (2)
# Fight or Flight
# Strange New World
# Unexpected
# Terra Nova
# The Andorian Incident
# Breaking the Ice
# Civilization
# Fortunate Son
# Cold Front
# Silent Enemy
# Dear Doctor
# Sleeping Dogs
# Shadows of P'Jem
# Shuttlepod One
# Fusion
# Rogue Planet
# Acquisition
# Oasis
# Detained
# Vox Sola
# Fallen Hero
# Desert Crossing
# Two Days and Two Nights
# Shockwave (1)
# Shockwave (2)
# Carbon Creek
# Minefield
# Dead Stop
# A Night in Sickbay
# Marauders
# The Seventh
# The Communicator
# Singularity
# Vanishing Point
# Precious Cargo
# The Catwalk
# Dawn
# Stigma
# Cease Fire
# Future Tense
# Canamar
# The Crossing
# Judgment
# Horizon
# The Breach
# Cogenitor
# Regeneration
# First Flight
# Bounty
# The Expanse
# The Xindi
# Anomaly
# Extinction
# Rajiin
# Impulse
# Exile
# The Shipment
# Twilight
# North Star
# Similitude
# Carpenter Street
# Chosen Realm
# Proving Ground
# Stratagem
# Harbinger
# Doctor's Orders
# Hatchery
# Azati Prime
# Damage
# The Forgotten
# E²
# The Council
# Countdown
# Zero Hour
# Storm Front (1)
# Storm Front (2)
# Home
# Borderland
# Cold Station 12
# The Augments
# The Forge
# Awakening
# Kir'Shara
# Daedalus
# Observer Effect
# Babel One
# United
# The Aenar
# Affliction
# Divergence
# Bound
# In a Mirror, Darkly (1)
# In a Mirror, Darkly (2)
# Demons
# Terra Prime
# These Are the Voyages...
# Total episodes:98
#
#
# SHOW NAME: Star Trek: Voyager
# Caretaker, Part I
# Caretaker, Part II
# Parallax
# Time and Again
# Phage
# The Cloud
# Eye of the Needle
# Ex Post Facto
# Emanations
# Prime Factors
# State of Flux
# Heroes and Demons
# Cathexis
# Faces
# Jetrel
# Learning Curve
# The 37's
# Initiations
# Projections
# Elogium
# Non Sequitur
# Twisted
# Parturition
# Persistence of Vision
# Tattoo
# Cold Fire
# Maneuvers
# Resistance
# Prototype
# Alliances
# Threshold
# Meld
# Dreadnought
# Death Wish
# Lifesigns
# Investigations
# Deadlock
# Innocence
# The Thaw
# Tuvix
# Resolutions
# Basics, Part I
# Basics, Part II
# Flashback
# The Chute
# The Swarm
# False Profits
# Remember
# Sacred Ground
# Future's End, Part I
# Future's End, Part II
# Warlord
# The Q and the Grey
# Macrocosm
# Fair Trade
# Alter Ego
# Coda
# Blood Fever
# Unity
# The Darkling
# Rise
# Favorite Son
# Before and After
# Real Life
# Distant Origin
# Displaced
# Worst Case Scenario
# Scorpion, Part I
# Scorpion, Part II
# The Gift
# Day of Honor
# Nemesis
# Revulsion
# The Raven
# Scientific Method
# Year of Hell, Part I
# Year of Hell, Part II
# Random Thoughts
# Concerning Flight
# Mortal Coil
# Waking Moments
# Message in a Bottle
# Hunters
# Prey
# Retrospect
# The Killing Game, Part I
# The Killing Game, Part II
# Vis à Vis
# The Omega Directive
# Unforgettable
# Living Witness
# Demon
# One
# Hope and Fear
# Night
# Drone
# Extreme Risk
# In the Flesh
# Once Upon a Time
# Timeless
# Infinite Regress
# Nothing Human
# Thirty Days
# Counterpoint
# Latent Image
# Bride of Chaotica!
# Gravity
# Bliss
# Dark Frontier, Part I
# Dark Frontier, Part II
# The Disease
# Course: Oblivion
# The Fight
# Think Tank
# Juggernaut
# Someone to Watch Over Me
# 11:59
# Relativity
# Warhead
# Equinox, Part I
# Equinox, Part II
# Survival Instinct
# Barge of the Dead
# Tinker, Tenor, Doctor, Spy
# Alice
# Riddles
# Dragon's Teeth
# One Small Step
# The Voyager Conspiracy
# Pathfinder
# Fair Haven
# Blink of an Eye
# Virtuoso
# Memorial
# Tsunkatse
# Collective
# Spirit Folk
# Ashes to Ashes
# Child's Play
# Good Shepherd
# Live Fast and Prosper
# Muse
# Fury
# Life Line
# The Haunting of Deck Twelve
# Unimatrix Zero, Part I
# Unimatrix Zero, Part II
# Imperfection
# Drive
# Repression
# Critical Care
# Inside Man
# Body and Soul
# Nightingale
# Flesh and Blood, Part I
# Flesh and Blood, Part II
# Shattered
# Lineage
# Repentance
# Prophecy
# The Void
# Workforce, Part I
# Workforce, Part II
# Human Error
# Q2
# Author, Author
# Friendship One
# Natural Law
# Homestead
# Renaissance Man
# Endgame, Part I
# Endgame, Part II
# Total episodes:172
#
#
# SHOW NAME: Star Trek Continues
# Pilgrim of Eternity
# Lolani
# Fairest of Them All
# The White Iris
# Divided We Stand
# Come Not Between the Dragons
# Embracing the Winds
# Still Treads the Shadow
# What Ships Are For
# To Boldly Go: Part I
# To Boldly Go: Part II
# Total episodes:11

# %%
# last.fm API information 
# Application name	Jack Driscoll
# API key	7c6c482dd53bf2f0ea0e3aea0f35f179
# Shared secret	27023be19f0d5e9f8717ee212b78b023
# Registered to	JMD500

apiKey = "7c6c482dd53bf2f0ea0e3aea0f35f179"

# %%
import requests 
import pprint

radioQuery = requests.get("http://ws.audioscrobbler.com/2.0/?method=artist.search&artist=radio&api_key="+apiKey+"&format=json").json()
#radioQuery["results"]["artistmatches"]["artist"]


# results key points to a dictionary that has a bunch of matches, artists with the name radio
# we want to get to the actual artist matches, a list of dicitonaries with artist matches , so we dig a little in the nested elements
artistMatches = radioQuery["results"]["artistmatches"]["artist"]
counter = 0
for artist in artistMatches:
    print(artist['name'])
    print("Listeners: "+artist['listeners'])
    counter+=1
    print()
print("There are "+str(counter)+ " artists!")
# Out:
# Radiohead
# Listeners: 4932649
#
# The Radio Dept.
# Listeners: 608601
#
# TV on the Radio
# Listeners: 1463752
#
# Radio Moscow
# Listeners: 268126
#
# Go Radio
# Listeners: 191486
#
# State Radio
# Listeners: 234464
#
# BBC Radio 4
# Listeners: 72564
#
# Bronze Radio Return
# Listeners: 181478
#
# All India Radio
# Listeners: 120462
#
# TBS RADIO 954kHz
# Listeners: 14767
#
# Beta Radio
# Listeners: 207951
#
# Radio Futura
# Listeners: 116854
#
# Red City Radio
# Listeners: 39243
#
# Radio 4
# Listeners: 146057
#
# Radio Birdman
# Listeners: 70958
#
# Danger Radio
# Listeners: 73000
#
# Porridge Radio
# Listeners: 44460
#
# Radio Citizen
# Listeners: 76072
#
# BBC Radio 5 Live
# Listeners: 33193
#
# RADIO TAPOK
# Listeners: 13575
#
# Radio Bagdad
# Listeners: 32337
#
# Primitive Radio Gods
# Listeners: 157068
#
# BBC Radio 1
# Listeners: 46469
#
# Radioactivity
# Listeners: 16389
#
# Radio Killer
# Listeners: 59973
#
# The One AM Radio
# Listeners: 79722
#
# radio ЧАЧА
# Listeners: 17615
#
# Radiorama
# Listeners: 56684
#
# Chicago Public Radio
# Listeners: 58447
#
# Radio
# Listeners: 22947
#
# There are 30 artists!

# %%
# by default, the last.fmi api returns results30 per page
#can change that amount by changing the limit in the query request
import requests 
import pprint
radioHeadQuery = requests.get("http://ws.audioscrobbler.com/2.0/?method=artist.search&artist=radiohead&api_key="+apiKey+"&format=json&limit=45").json()

artistCounter = 1
for artist in radioHeadQuery["results"]["artistmatches"]["artist"]:
    print(str(artistCounter)+". Band Name: "+artist["name"])
    artistCounter+=1
# Out:
# 1. Band Name: Radiohead
# 2. Band Name: Radiohead VS Dave Brubeck
# 3. Band Name: Radiohead Tribute
# 4. Band Name: Radiohead - Eric Gorfain
# 5. Band Name: Dub Tribute To Radiohead
# 6. Band Name: Radiohead & El Lele
# 7. Band Name: Radiohead's Thom Yorke & Jonny Greenwood
# 8. Band Name: µçÌ¨Ë¾Áî(Radiohead)
# 9. Band Name: El Lele de Los Van Van feat. Radiohead (samples)
# 10. Band Name: Radiohead & Hans Zimmer
# 11. Band Name: The Bluegrass Tribute to Radiohead
# 12. Band Name: Ember Island x Radiohead
# 13. Band Name: The Smashing Pumpkins, Radiohead & Smashmouth
# 14. Band Name: Radiohead vs Morcheeba vs Digitalism
# 15. Band Name: Radiohead/Musicfire.in
# 16. Band Name: Radiohead Tribute Band
# 17. Band Name: Radiohead/Michael Stipe
# 18. Band Name: Radiohead+Ani DeFranco
# 19. Band Name: Radiohead Meets The Police
# 20. Band Name: Radiohead feat. PJ Harvey
# 21. Band Name: Radiohead mixed by AmpLive
# 22. Band Name: Radiohead -- In Rainbows (Discs Box)
# 23. Band Name: [HD] Radiohead
# 24. Band Name: Radiohead  Vs. Noir Desir
# 25. Band Name: Radiohead x SALEM
# 26. Band Name: Baby Rock Radiohead
# 27. Band Name: Radiohead & Christopher O' Reilly
# 28. Band Name: Radiohead(라디오헤드)
# 29. Band Name: Radiohead (Eskmo Remix)
# 30. Band Name: Hans Zimmer & Radiohead
# 31. Band Name: Radiohead ft Portishead
# 32. Band Name: Radiohead & Sigur Ros
# 33. Band Name: Radiohead & Björk
# 34. Band Name: Radiohead & Echo & The Bunnymen
# 35. Band Name: Radiohead vs. Nirvana vs. Nine Inch Nails
# 36. Band Name: Radiohead - rabablues.blogspot.com
# 37. Band Name: Radiohead - Topic
# 38. Band Name: Louis Armstrong VS Radiohead
# 39. Band Name: Radiohead VS Pink Floyd
# 40. Band Name: Kanye West vs. Radiohead
# 41. Band Name: Radiohead-A Moon Shaped Pool(2016)
# 42. Band Name: Thom Yorke and Johnny Greenwood (Radiohead)
# 43. Band Name: Radiohead, U-God and dj BC
# 44. Band Name: Radiohead Side B
# 45. Band Name: Radiohead II

# %%
#if you want to see all the keys in a dictionary use the .keys method
radioHeadQuery["results"]["artistmatches"]["artist"][0].keys()
# Out:
# dict_keys(['name', 'listeners', 'mbid', 'url', 'streamable', 'image'])

# %%
rHeadMbid= radioHeadQuery["results"]["artistmatches"]["artist"][0]["mbid"]

C = requests.get("http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key="+apiKey+"&format=json&mbid="+rHeadMbid).json()
#pprint.pprint(radioheadArtistQuery)
radioheadArtistQuery["artist"]["bio"].keys()
print(radioheadArtistQuery["artist"]["bio"]["content"]
# Out:
#   File "<ipython-input-1-700f355117e9>", line 6
#     print(radioheadArtistQuery["artist"]["bio"]["content"]
#                                                                    ^
# SyntaxError: unexpected EOF while parsing
